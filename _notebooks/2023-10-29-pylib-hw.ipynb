# %% [markdown]
# ---
# layout: post
# title: Python Libraries Homework
# description: Python libraries homework assignment
# courses: { compsci: {week: 10} }
# type: ccc
# permalink: /teamteach/pylib
# comments: true
# ---

# %% [markdown]
# ## HOMEWORK 1
#
# Create a GPA calculator using Pandas and Matplot libraries and make:
# 1) A dataframe
# 2) A specified dictionary
# 3) and a print function that outputs the final GPA
#
# Extra points can be earned with creativity.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# sample data for classes
data = {'Subject': ['Math', 'Biology', 'History', 'English', 'CompSci'],
        'Credits': [5, 5, 5, 5, 5],
        'Grade': ['A', 'A', 'B', 'A', 'B']}
df = pd.DataFrame(data)

# grade point dictionary
grade_points = {'A': 4.0, 'B': 3.0, 'C': 2.0, 'D': 1.0, 'F': 0.0,}

# gpa calculation
def calculate_gpa(SampleData):
    total_credits = 0
    total_grade_points = 0
    for index, row in SampleData.iterrows():
        credit = row['Credits']
        grade = row['Grade']
        if grade in grade_points:
            grade_point = grade_points[grade]
            total_credits += credit
            total_grade_points += credit * grade_point
    gpa = total_grade_points / total_credits
    return gpa

# final gpa output
final_gpa = calculate_gpa(df)
print(f'Final GPA: {final_gpa:.2f}')

grade_points_list = []
for index, row in df.iterrows():
    grade = row['Grade']
    grade_points_list.append(grade_points.get(grade, 0))

subjects = df['Subject'].to_numpy()

# gpa bar chart
plt.figure(figsize=(10, 5))
plt.bar(subjects, df['Credits'], color='lightblue', label='Credits')
plt.ylabel('Credits')
plt.twinx()
plt.plot(subjects, grade_points_list, marker='o', color='orange', label='Grade Points')
plt.ylabel('Grade Points')
plt.title('GPA by Subject')
plt.legend(loc='upper left')
plt.show()
# Out:
# Final GPA: 3.60

# %% [markdown]
# ## HOMEWORK 2
#
# Import and use the "random" library to generate 50 different points from the range 0-100, then display the randomized data using a scatter plot.
#
# Extra points can be earned with creativity.

# %%
import random
import matplotlib.pyplot as plt

# 50 random points w/in 0 and 100
random_data = [(random.randint(0, 100), random.randint(0, 100)) for _ in range(50)]

# random x, y
x_data, y_data = zip(*random_data)

# weird point sizing
point_sizes = [random.randint(20, 100) for _ in range(50)]

# scatterplot display
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, c='blue', s=point_sizes, alpha=0.6, edgecolors='black', label='Random Points')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Random Scatterplot Data')
plt.legend()

plt.show()
